# %%
# !pip install -Uqq fastai

# %%
from fastai.vision.all import *

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/MasterCourse/Car Recognizer
# Out:
# /content/drive/My Drive/MasterCourse/Car Recognizer

# %%
version = 0
img_path = "test_images"
model_path = f"models/car-recognizer-v{version}.pkl"

# %%
model = load_learner(model_path)

# %% [markdown]
# ## Inference 1

# %%
img = Image.open(f"{img_path}/sedan.jpg")
img.to_thumb(128, 128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x72>

# %%
model.predict(f"{img_path}/sedan.jpg")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('sedan car',
#  TensorBase(7),
#  TensorBase([2.9904e-06, 7.5141e-05, 2.0512e-02, 2.4748e-05, 5.7290e-03,
#              8.3745e-04, 6.8037e-05, 9.6680e-01, 7.5836e-06, 5.9387e-03,
#              7.1833e-06]))

# %% [markdown]
# ## Inference 2

# %%
img = Image.open(f"{img_path}/minivan.jpg")
img.to_thumb(128, 128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x69>

# %%
model.predict(f"{img_path}/minivan.jpg")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('sedan car',
#  TensorBase(7),
#  TensorBase([1.8113e-01, 3.4571e-03, 2.1801e-01, 4.3642e-03, 6.7260e-03,
#              1.0501e-01, 1.2518e-04, 4.5622e-01, 7.3885e-05, 2.4834e-02,
#              4.5188e-05]))

# %%
img = Image.open(f"{img_path}/00.jpg")
img.to_thumb(128, 128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x64>

# %%
model.predict(f"{img_path}/00.jpg")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('hatchback car',
#  TensorBase(2),
#  TensorBase([1.7811e-07, 1.2825e-05, 8.3122e-01, 2.6523e-07, 4.6055e-02,
#              1.2330e-06, 8.9347e-08, 1.2196e-01, 3.5595e-05, 7.1062e-04,
#              4.9421e-09]))

# %%
img = Image.open(f"{img_path}/truck.jpg")
img.to_thumb(128, 128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x78>

# %%
model.predict(f"{img_path}/truck.jpg")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('truck car',
#  TensorBase(10),
#  TensorBase([1.0368e-04, 1.8446e-04, 1.5853e-03, 3.1592e-04, 2.6065e-02,
#              1.8679e-03, 5.9761e-05, 4.0605e-02, 2.3600e-05, 4.3677e-01,
#              4.9242e-01]))

# %%
img = Image.open(f"{img_path}/suv.jpg")
img.to_thumb(128, 128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x67>

# %%
model.predict(f"{img_path}/suv.jpg")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('suv car',
#  TensorBase(9),
#  TensorBase([8.4313e-08, 6.7614e-07, 9.4724e-04, 3.4839e-08, 7.3378e-05,
#              7.6112e-07, 2.2686e-07, 6.7326e-03, 8.9936e-08, 9.9224e-01,
#              3.8829e-06]))

# %%
img = Image.open(f"{img_path}/musclecar.jpg")
img.to_thumb(128, 128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model.predict(f"{img_path}/musclecar.jpg")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('muscle car',
#  TensorBase(6),
#  TensorBase([1.9685e-05, 1.1197e-03, 8.6242e-05, 2.7485e-05, 8.7711e-07,
#              9.7941e-08, 9.9863e-01, 5.1913e-05, 1.2566e-05, 2.3651e-05,
#              2.4129e-05]))
